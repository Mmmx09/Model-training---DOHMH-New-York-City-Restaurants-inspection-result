# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('cleaned_restaurant_inspection_data_3.csv') 
df.head(3)
# Out:
# /var/folders/5y/b6cqgch533773c9dm5spwwx00000gn/T/ipykernel_89679/2182199294.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('cleaned_restaurant_inspection_data_3.csv')
#       CAMIS                    DBA   BORO BUILDING              STREET  \
# 0  30075445  MORRIS PARK BAKE SHOP  Bronx     1007  MORRIS PARK AVENUE
# 1  30075445  MORRIS PARK BAKE SHOP  Bronx     1007  MORRIS PARK AVENUE
# 2  30075445  MORRIS PARK BAKE SHOP  Bronx     1007  MORRIS PARK AVENUE
#
#    ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0  10462.0  7188924968  Bakery Products/Desserts
# 1  10462.0  7188924968  Bakery Products/Desserts
# 2  10462.0  7188924968  Bakery Products/Desserts
#
#                                               ACTION VIOLATION CODE  ...  \
# 0  Establishment Closed by DOHMH. Violations were...            06D  ...
# 1  Establishment Closed by DOHMH. Violations were...            08C  ...
# 2  Establishment Closed by DOHMH. Violations were...            04L  ...
#
#   Census Tract        BIN           BBL   NTA  \
# 0      25200.0  2045445.0  2.041270e+09  BX37
# 1      25200.0  2045445.0  2.041270e+09  BX37
# 2      25200.0  2045445.0  2.041270e+09  BX37
#
#                                    Location  days_since_last  \
# 0  POINT (-73.855971889932 40.848231224526)            730.0
# 1  POINT (-73.855971889932 40.848231224526)              0.0
# 2  POINT (-73.855971889932 40.848231224526)              0.0
#
#    avg_last_3_scores  inspection_year  inspection_month  inspection_weekday
# 0           25.02185             2023                 1                   1
# 1           21.00000             2023                 1                   1
# 2           21.00000             2023                 1                   1
#
# [3 rows x 28 columns]
